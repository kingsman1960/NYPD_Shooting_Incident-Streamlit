# %%
import folium as fl
import pandas as pd
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
map1 = fl.Map(location=[40.730610, -73.935242], tiles='stamenterrain', zoom_start= 11.3)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Cases = pd.read_csv("NYPD_Shooting.csv")
Cases.head()
# Out:
#    INCIDENT_KEY  OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 0     169180023  09/09/2017    3:57:00  STATEN ISLAND       120
# 1     169180027  09/09/2017   22:15:00          BRONX        50
# 2     169180025  09/09/2017   18:35:00       BROOKLYN        79
# 3     169180024  09/09/2017   15:20:00       BROOKLYN        67
# 4     169180022  09/09/2017    0:20:00       BROOKLYN        61
#
#    JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                0.0                        NaN                    False
# 1                0.0                        NaN                    False
# 2                2.0  MULTI DWELL - PUBLIC HOUS                    False
# 3                0.0                        NaN                    False
# 4                2.0  MULTI DWELL - PUBLIC HOUS                    False
#
#   PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# 0            NaN      NaN       NaN         25-44       M
# ...

# %%
# Let's see only Brooklyn cases.
df = pd.read_csv("NYPD_Shooting_Brooklyn.csv")
#brooklyn = Cases['BORO'].replace(to_replace=['BRONX','BROOKLYN','MANHATTAN','QUEENS','STATEN ISLAND'], value=[0,1,2,3,4],inplace=True)
#brooklyn = Cases[Cases.BORO.BROOKLYN]
df
# Out:
#       INCIDENT_KEY  OCCUR_DATE OCCUR_TIME      BORO  PRECINCT  \
# 0        169180025  09/09/2017   18:35:00  BROOKLYN        79
# 1        169180024  09/09/2017   15:20:00  BROOKLYN        67
# 2        169180022  09/09/2017    0:20:00  BROOKLYN        61
# 3        156603440  09/09/2016   20:58:00  BROOKLYN        67
# 4        146013532  09/09/2015   19:03:00  BROOKLYN        77
# ...            ...         ...        ...       ...       ...
# 9196     191949899  01/04/2019   15:49:00  BROOKLYN        61
# 9197     191853461  01/04/2019    2:20:00  BROOKLYN        60
# 9198     191790873  01/02/2019   13:34:00  BROOKLYN        79
# 9199     191739125  01/01/2019    5:40:00  BROOKLYN        88
# 9200     191709964  01/01/2019    4:26:00  BROOKLYN        75
#
#       JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                     2  MULTI DWELL - PUBLIC HOUS                    False
# ...

# %%
df['OCCUR_DATE'] = pd.to_datetime(df['OCCUR_DATE'])
df.head()
# Out:
#    INCIDENT_KEY OCCUR_DATE OCCUR_TIME      BORO  PRECINCT  JURISDICTION_CODE  \
# 0     169180025 2017-09-09   18:35:00  BROOKLYN        79                  2
# 1     169180024 2017-09-09   15:20:00  BROOKLYN        67                  0
# 2     169180022 2017-09-09    0:20:00  BROOKLYN        61                  2
# 3     156603440 2016-09-09   20:58:00  BROOKLYN        67                  0
# 4     146013532 2015-09-09   19:03:00  BROOKLYN        77                  0
#
#                LOCATION_DESC  STATISTICAL_MURDER_FLAG PERP_AGE_GROUP PERP_SEX  \
# 0  MULTI DWELL - PUBLIC HOUS                    False            NaN      NaN
# 1                        NaN                    False          18-24        M
# 2  MULTI DWELL - PUBLIC HOUS                    False            NaN      NaN
# 3    MULTI DWELL - APT BUILD                    False          25-44        M
# 4                        NaN                     True          25-44        M
#
# ...

# %%
# 지도 생성
# 지도에 마커 포인트 추가
# Create a map
map2 = fl.Map(location=[40.650002, -73.949997], tiles='stamenterrain', zoom_start= 12)

HeatMap(data=df[['LATITUDE', 'LONGITUDE']], radius=11).add_to(map2)

# Display the map
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 생성
# 지도에 마커 포인트 추가
# Create a map
map3 = fl.Map(location=[40.730610, -73.935242], tiles='stamenterrain', zoom_start= 9.8)

HeatMap(data=Cases[['LATITUDE', 'LONGITUDE']], radius=11).add_to(map3)

# Display the map
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
